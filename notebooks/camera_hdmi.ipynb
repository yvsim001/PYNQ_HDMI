# %% [markdown]
# # Caméra USB → HDMI 720p (PYNQ-Z1)
# Voir `src/` pour les scripts complets. Ce notebook reprend les étapes une à une.

# %%
import time, cv2
import numpy as np
from pynq import Overlay, allocate, MMIO
ol = Overlay('/home/xilinx/jupyter_notebooks/video/design_1.bit')
print(list(ol.ip_dict.keys()))

# %% [markdown]
# ## 1. Test mire statique — voir src/test_colorbar.py

# %% [markdown]
# ## 2. Test capture caméra — voir src/test_camera_capture.py

# %% [markdown]
# ## 3. Mesure du décalage — voir src/measure_offset.py

# %% [markdown]
# ## 4. Flux live — voir src/live_camera_hdmi.py
